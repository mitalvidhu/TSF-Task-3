# %% [markdown]
# # Exploratory Data Analysis-Retail

# %% [markdown]
# ## By: Vidhu Mital

# %% [markdown]
# ### Perform data analysis on the 'SampleSuperstore' dataset and as a business manager, try to find out the weak areas where work can be done to earn more profit

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
original_df = pd.read_csv('Superstore.csv')
original_df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
original_df.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %%
original_df[original_df.Profit == original_df.Profit.min()]
# Out:
#            Ship Mode   Segment        Country       City State  Postal Code  \
# 7772  Standard Class  Consumer  United States  Lancaster  Ohio        43130
#
#      Region    Category Sub-Category     Sales  Quantity  Discount    Profit
# 7772   East  Technology     Machines  4499.985         5       0.7 -6599.978

# %%
original_df[original_df.Profit == original_df.Profit.max()]
# Out:
#            Ship Mode    Segment        Country       City    State  \
# 6826  Standard Class  Corporate  United States  Lafayette  Indiana
#
#       Postal Code   Region    Category Sub-Category     Sales  Quantity  \
# 6826        47905  Central  Technology      Copiers  17499.95         5
#
#       Discount    Profit
# 6826       0.0  8399.976

# %%
original_df[original_df.Sales == original_df.Sales.max()]
# Out:
#            Ship Mode      Segment        Country          City    State  \
# 2697  Standard Class  Home Office  United States  Jacksonville  Florida
#
#       Postal Code Region    Category Sub-Category     Sales  Quantity  \
# 2697        32216  South  Technology     Machines  22638.48         6
#
#       Discount     Profit
# 2697       0.5 -1811.0784

# %%
original_df[original_df.Sales == original_df.Sales.min()]
# Out:
#            Ship Mode   Segment        Country     City  State  Postal Code  \
# 4101  Standard Class  Consumer  United States  Houston  Texas        77095
#
#        Region         Category Sub-Category  Sales  Quantity  Discount  Profit
# 4101  Central  Office Supplies   Appliances  0.444         1       0.8   -1.11

# %%
sns.set(rc={"figure.figsize":(8, 4)})
sns.barplot(x = 'Profit', y = 'Discount', data = original_df.head(10))
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Discount'>

# %% [markdown]
# ## When discount is high, the sales are also high but the profit is negative i.e. the company suffers net loss

# %%
sns.set(rc={"figure.figsize":(8, 4)})
sns.barplot(x = 'Sales', y = 'Discount', data = original_df.head(10))
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Discount'>

# %%
original_df['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
sns.set(rc={"figure.figsize":(40, 20)})
sns.lineplot(x = 'Profit', y = 'Discount', data = original_df)
plt.xlabel('Profit (in $)', fontsize = 50)
plt.ylabel('Discount Offered', fontsize = 50)
# Out:
# Text(0, 0.5, 'Discount Offered')

# %% [markdown]
# ## Profit is positive when the discount offered is less than 20%

# %%
sns.set(rc={"figure.figsize":(40, 20)})
sns.lineplot(x = 'Sales', y = 'Discount', data = original_df)
plt.xlabel('Sales (in $)', fontsize = 50)
plt.ylabel('Discount Offered', fontsize = 50)
# Out:
# Text(0, 0.5, 'Discount Offered')

# %% [markdown]
# ## The company should refrain from offering very high discounts to the customers. Although high discounts will enable a lot more sales, the net profit earned is low and sometimes negative
